# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 64 # Number of bins in the color histogram
# num_color_bins = 32 # Number of bins in the color histogram for svm
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-8, 1e-7, 2e-7, 3e-7, 3e-7]
regularization_strengths = [3e3, 3e4, 4e4, 5e4, 6e4, 7e4, 5e5, 8e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=1500)
        
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        
        training_accuracy = np.mean(y_train_pred == y_train)
        validation_accuracy = np.mean(y_val_pred == y_val)
        
        results[(lr, reg)] = (training_accuracy, validation_accuracy)
        
        if best_val < validation_accuracy:
            best_val = validation_accuracy
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-08 reg 3.000000e+03 train accuracy: 0.103041 val accuracy: 0.095000
# lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.114796 val accuracy: 0.105000
# lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.106184 val accuracy: 0.120000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.080755 val accuracy: 0.089000
# lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.111347 val accuracy: 0.103000
# lr 1.000000e-08 reg 7.000000e+04 train accuracy: 0.091714 val accuracy: 0.084000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.357408 val accuracy: 0.348000
# lr 1.000000e-08 reg 8.000000e+05 train accuracy: 0.423122 val accuracy: 0.423000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.419776 val accuracy: 0.413000
# lr 1.000000e-07 reg 3.000000e+03 train accuracy: 0.136980 val accuracy: 0.133000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.334347 val accuracy: 0.346000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.409408 val accuracy: 0.417000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.423694 val accuracy: 0.430000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.424755 val accuracy: 0.426000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.424082 val accuracy: 0.430000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.428041 val accuracy: 0.425000
# lr 1.000000e-07 reg 8.000000e+05 train accuracy: 0.418592 val accuracy: 0.431000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.391735 val accuracy: 0.410000
# lr 2.000000e-07 reg 3.000000e+03 train accuracy: 0.142449 val accuracy: 0.128000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.426449 val accuracy: 0.432000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.427020 val accuracy: 0.428000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.424735 val accuracy: 0.433000
# lr 2.000000e-07 reg 6.000000e+04 train accuracy: 0.422020 val accuracy: 0.411000
# lr 2.000000e-07 reg 7.000000e+04 train accuracy: 0.426204 val accuracy: 0.441000
# lr 2.000000e-07 reg 5.000000e+05 train accuracy: 0.415204 val accuracy: 0.437000
# lr 2.000000e-07 reg 8.000000e+05 train accuracy: 0.394592 val accuracy: 0.387000
# lr 2.000000e-07 reg 5.000000e+06 train accuracy: 0.344776 val accuracy: 0.324000
# lr 3.000000e-07 reg 3.000000e+03 train accuracy: 0.197224 val accuracy: 0.207000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.421531 val accuracy: 0.419000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.423143 val accuracy: 0.423000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.423367 val accuracy: 0.431000
# lr 3.000000e-07 reg 6.000000e+04 train accuracy: 0.427102 val accuracy: 0.434000
# lr 3.000000e-07 reg 7.000000e+04 train accuracy: 0.422673 val accuracy: 0.414000
# lr 3.000000e-07 reg 5.000000e+05 train accuracy: 0.410122 val accuracy: 0.426000
# lr 3.000000e-07 reg 8.000000e+05 train accuracy: 0.409918 val accuracy: 0.420000
# lr 3.000000e-07 reg 5.000000e+06 train accuracy: 0.270857 val accuracy: 0.274000
# best validation accuracy achieved during cross-validation: 0.441000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.435

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 209)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

# net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_acc = -1  # The highest validation accuracy that we have seen so far.

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# there are a little bit of extra values 
# but it's interesting to see how accuracy changes
learning_rates = [1e-2, 2e-2, 3e-2, 4e-2, 1e-1, 2e-1, 3e-1, 8e-1]
# learning_rates = np.logspace(-6, 6, num=10)
regularization_strengths = [1e-4, 1e-3, 3e-3, 0.01, 0.05, 0.1, 0.15, 0.2, 0.25]

for hidden_dim in [100, 200, 300, 500]:
    print("-----{0}------".format(hidden_dim))
    for lr in learning_rates:
        for reg in regularization_strengths:
            net = TwoLayerNet(input_dim, hidden_dim, num_classes)
            # Train the network
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                        num_iters=2000, batch_size=200,
                        learning_rate=lr, learning_rate_decay=0.95,
                        reg=reg, verbose=False)
            
            # Predict on the validation set
            val_acc = (net.predict(X_val_feats) == y_val).mean()
            print('Validation accuracy: ', val_acc, "lr: ", lr, "reg: ", reg)
            if best_acc < val_acc:
                best_acc = val_acc
                best_net = net
#             results[(lr, reg)] = val_acc
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# -----100------
# Validation accuracy:  0.183 lr:  0.01 reg:  0.0001
# Validation accuracy:  0.191 lr:  0.01 reg:  0.001
# Validation accuracy:  0.223 lr:  0.01 reg:  0.003
# Validation accuracy:  0.16 lr:  0.01 reg:  0.01
# Validation accuracy:  0.199 lr:  0.01 reg:  0.05
# Validation accuracy:  0.195 lr:  0.01 reg:  0.1
# Validation accuracy:  0.145 lr:  0.01 reg:  0.15
# Validation accuracy:  0.104 lr:  0.01 reg:  0.2
# Validation accuracy:  0.079 lr:  0.01 reg:  0.25
# Validation accuracy:  0.357 lr:  0.02 reg:  0.0001
# Validation accuracy:  0.365 lr:  0.02 reg:  0.001
# Validation accuracy:  0.358 lr:  0.02 reg:  0.003
# Validation accuracy:  0.35 lr:  0.02 reg:  0.01
# Validation accuracy:  0.298 lr:  0.02 reg:  0.05
# Validation accuracy:  0.278 lr:  0.02 reg:  0.1
# Validation accuracy:  0.223 lr:  0.02 reg:  0.15
# Validation accuracy:  0.198 lr:  0.02 reg:  0.2
# Validation accuracy:  0.141 lr:  0.02 reg:  0.25
# Validation accuracy:  0.452 lr:  0.03 reg:  0.0001
# Validation accuracy:  0.462 lr:  0.03 reg:  0.001
# Validation accuracy:  0.454 lr:  0.03 reg:  0.003
# Validation accuracy:  0.436 lr:  0.03 reg:  0.01
# Validation accuracy:  0.411 lr:  0.03 reg:  0.05
# Validation accuracy:  0.349 lr:  0.03 reg:  0.1
# Validation accuracy:  0.28 lr:  0.03 reg:  0.15
# Validation accuracy:  0.27 lr:  0.03 reg:  0.2
# Validation accuracy:  0.208 lr:  0.03 reg:  0.25
# Validation accuracy:  0.503 lr:  0.04 reg:  0.0001
# Validation accuracy:  0.504 lr:  0.04 reg:  0.001
# Validation accuracy:  0.496 lr:  0.04 reg:  0.003
# Validation accuracy:  0.499 lr:  0.04 reg:  0.01
# Validation accuracy:  0.455 lr:  0.04 reg:  0.05
# Validation accuracy:  0.377 lr:  0.04 reg:  0.1
# Validation accuracy:  0.325 lr:  0.04 reg:  0.15
# Validation accuracy:  0.289 lr:  0.04 reg:  0.2
# Validation accuracy:  0.235 lr:  0.04 reg:  0.25
# Validation accuracy:  0.555 lr:  0.1 reg:  0.0001
# Validation accuracy:  0.55 lr:  0.1 reg:  0.001
# Validation accuracy:  0.546 lr:  0.1 reg:  0.003
# Validation accuracy:  0.54 lr:  0.1 reg:  0.01
# Validation accuracy:  0.522 lr:  0.1 reg:  0.05
# Validation accuracy:  0.461 lr:  0.1 reg:  0.1
# Validation accuracy:  0.386 lr:  0.1 reg:  0.15
# Validation accuracy:  0.309 lr:  0.1 reg:  0.2
# Validation accuracy:  0.28 lr:  0.1 reg:  0.25
# Validation accuracy:  0.574 lr:  0.2 reg:  0.0001
# Validation accuracy:  0.567 lr:  0.2 reg:  0.001
# Validation accuracy:  0.564 lr:  0.2 reg:  0.003
# Validation accuracy:  0.544 lr:  0.2 reg:  0.01
# Validation accuracy:  0.509 lr:  0.2 reg:  0.05
# Validation accuracy:  0.446 lr:  0.2 reg:  0.1
# Validation accuracy:  0.382 lr:  0.2 reg:  0.15
# Validation accuracy:  0.376 lr:  0.2 reg:  0.2
# Validation accuracy:  0.298 lr:  0.2 reg:  0.25
# Validation accuracy:  0.57 lr:  0.3 reg:  0.0001
# Validation accuracy:  0.578 lr:  0.3 reg:  0.001
# Validation accuracy:  0.577 lr:  0.3 reg:  0.003
# Validation accuracy:  0.553 lr:  0.3 reg:  0.01
# Validation accuracy:  0.479 lr:  0.3 reg:  0.05
# Validation accuracy:  0.43 lr:  0.3 reg:  0.1
# Validation accuracy:  0.403 lr:  0.3 reg:  0.15
# Validation accuracy:  0.387 lr:  0.3 reg:  0.2
# Validation accuracy:  0.284 lr:  0.3 reg:  0.25
# Validation accuracy:  0.565 lr:  0.8 reg:  0.0001
# Validation accuracy:  0.568 lr:  0.8 reg:  0.001
# Validation accuracy:  0.568 lr:  0.8 reg:  0.003
# Validation accuracy:  0.519 lr:  0.8 reg:  0.01
# Validation accuracy:  0.491 lr:  0.8 reg:  0.05
# Validation accuracy:  0.37 lr:  0.8 reg:  0.1
# Validation accuracy:  0.317 lr:  0.8 reg:  0.15
# Validation accuracy:  0.29 lr:  0.8 reg:  0.2
# Validation accuracy:  0.26 lr:  0.8 reg:  0.25
# -----200------
# Validation accuracy:  0.241 lr:  0.01 reg:  0.0001
# Validation accuracy:  0.235 lr:  0.01 reg:  0.001
# Validation accuracy:  0.224 lr:  0.01 reg:  0.003
# Validation accuracy:  0.22 lr:  0.01 reg:  0.01
# Validation accuracy:  0.189 lr:  0.01 reg:  0.05
# Validation accuracy:  0.125 lr:  0.01 reg:  0.1
# Validation accuracy:  0.146 lr:  0.01 reg:  0.15
# Validation accuracy:  0.087 lr:  0.01 reg:  0.2
# Validation accuracy:  0.087 lr:  0.01 reg:  0.25
# Validation accuracy:  0.372 lr:  0.02 reg:  0.0001
# Validation accuracy:  0.364 lr:  0.02 reg:  0.001
# Validation accuracy:  0.373 lr:  0.02 reg:  0.003
# Validation accuracy:  0.369 lr:  0.02 reg:  0.01
# Validation accuracy:  0.323 lr:  0.02 reg:  0.05
# Validation accuracy:  0.289 lr:  0.02 reg:  0.1
# Validation accuracy:  0.258 lr:  0.02 reg:  0.15
# Validation accuracy:  0.175 lr:  0.02 reg:  0.2
# Validation accuracy:  0.152 lr:  0.02 reg:  0.25
# Validation accuracy:  0.465 lr:  0.03 reg:  0.0001
# Validation accuracy:  0.476 lr:  0.03 reg:  0.001
# Validation accuracy:  0.472 lr:  0.03 reg:  0.003
# Validation accuracy:  0.449 lr:  0.03 reg:  0.01
# Validation accuracy:  0.409 lr:  0.03 reg:  0.05
# Validation accuracy:  0.35 lr:  0.03 reg:  0.1
# Validation accuracy:  0.298 lr:  0.03 reg:  0.15
# Validation accuracy:  0.282 lr:  0.03 reg:  0.2
# Validation accuracy:  0.207 lr:  0.03 reg:  0.25
# Validation accuracy:  0.504 lr:  0.04 reg:  0.0001
# Validation accuracy:  0.506 lr:  0.04 reg:  0.001
# Validation accuracy:  0.507 lr:  0.04 reg:  0.003
# Validation accuracy:  0.503 lr:  0.04 reg:  0.01
# Validation accuracy:  0.447 lr:  0.04 reg:  0.05
# Validation accuracy:  0.385 lr:  0.04 reg:  0.1
# Validation accuracy:  0.315 lr:  0.04 reg:  0.15
# Validation accuracy:  0.3 lr:  0.04 reg:  0.2
# Validation accuracy:  0.27 lr:  0.04 reg:  0.25
# Validation accuracy:  0.55 lr:  0.1 reg:  0.0001
# Validation accuracy:  0.556 lr:  0.1 reg:  0.001
# Validation accuracy:  0.541 lr:  0.1 reg:  0.003
# Validation accuracy:  0.542 lr:  0.1 reg:  0.01
# Validation accuracy:  0.504 lr:  0.1 reg:  0.05
# Validation accuracy:  0.43 lr:  0.1 reg:  0.1
# Validation accuracy:  0.397 lr:  0.1 reg:  0.15
# Validation accuracy:  0.344 lr:  0.1 reg:  0.2
# Validation accuracy:  0.285 lr:  0.1 reg:  0.25
# Validation accuracy:  0.582 lr:  0.2 reg:  0.0001
# Validation accuracy:  0.591 lr:  0.2 reg:  0.001
# Validation accuracy:  0.573 lr:  0.2 reg:  0.003
# Validation accuracy:  0.544 lr:  0.2 reg:  0.01
# Validation accuracy:  0.506 lr:  0.2 reg:  0.05
# Validation accuracy:  0.443 lr:  0.2 reg:  0.1
# Validation accuracy:  0.403 lr:  0.2 reg:  0.15
# Validation accuracy:  0.374 lr:  0.2 reg:  0.2
# Validation accuracy:  0.274 lr:  0.2 reg:  0.25
# Validation accuracy:  0.589 lr:  0.3 reg:  0.0001
# Validation accuracy:  0.584 lr:  0.3 reg:  0.001
# Validation accuracy:  0.583 lr:  0.3 reg:  0.003
# Validation accuracy:  0.559 lr:  0.3 reg:  0.01
# Validation accuracy:  0.511 lr:  0.3 reg:  0.05
# Validation accuracy:  0.454 lr:  0.3 reg:  0.1
# Validation accuracy:  0.391 lr:  0.3 reg:  0.15
# Validation accuracy:  0.34 lr:  0.3 reg:  0.2
# Validation accuracy:  0.255 lr:  0.3 reg:  0.25
# Validation accuracy:  0.564 lr:  0.8 reg:  0.0001
# Validation accuracy:  0.58 lr:  0.8 reg:  0.001
# Validation accuracy:  0.571 lr:  0.8 reg:  0.003
# Validation accuracy:  0.542 lr:  0.8 reg:  0.01
# Validation accuracy:  0.458 lr:  0.8 reg:  0.05
# Validation accuracy:  0.423 lr:  0.8 reg:  0.1
# Validation accuracy:  0.31 lr:  0.8 reg:  0.15
# Validation accuracy:  0.322 lr:  0.8 reg:  0.2
# Validation accuracy:  0.263 lr:  0.8 reg:  0.25
# -----300------
# Validation accuracy:  0.225 lr:  0.01 reg:  0.0001
# Validation accuracy:  0.223 lr:  0.01 reg:  0.001
# Validation accuracy:  0.247 lr:  0.01 reg:  0.003
# Validation accuracy:  0.212 lr:  0.01 reg:  0.01
# Validation accuracy:  0.169 lr:  0.01 reg:  0.05
# Validation accuracy:  0.194 lr:  0.01 reg:  0.1
# Validation accuracy:  0.127 lr:  0.01 reg:  0.15
# Validation accuracy:  0.087 lr:  0.01 reg:  0.2
# Validation accuracy:  0.107 lr:  0.01 reg:  0.25
# Validation accuracy:  0.379 lr:  0.02 reg:  0.0001
# Validation accuracy:  0.381 lr:  0.02 reg:  0.001
# Validation accuracy:  0.368 lr:  0.02 reg:  0.003
# Validation accuracy:  0.371 lr:  0.02 reg:  0.01
# Validation accuracy:  0.348 lr:  0.02 reg:  0.05
# Validation accuracy:  0.292 lr:  0.02 reg:  0.1
# Validation accuracy:  0.257 lr:  0.02 reg:  0.15
# Validation accuracy:  0.202 lr:  0.02 reg:  0.2
# Validation accuracy:  0.168 lr:  0.02 reg:  0.25
# Validation accuracy:  0.476 lr:  0.03 reg:  0.0001
# Validation accuracy:  0.48 lr:  0.03 reg:  0.001
# Validation accuracy:  0.474 lr:  0.03 reg:  0.003
# Validation accuracy:  0.461 lr:  0.03 reg:  0.01
# Validation accuracy:  0.421 lr:  0.03 reg:  0.05
# Validation accuracy:  0.351 lr:  0.03 reg:  0.1
# Validation accuracy:  0.297 lr:  0.03 reg:  0.15
# Validation accuracy:  0.283 lr:  0.03 reg:  0.2
# Validation accuracy:  0.213 lr:  0.03 reg:  0.25
# Validation accuracy:  0.497 lr:  0.04 reg:  0.0001
# Validation accuracy:  0.506 lr:  0.04 reg:  0.001
# Validation accuracy:  0.497 lr:  0.04 reg:  0.003
# Validation accuracy:  0.498 lr:  0.04 reg:  0.01
# Validation accuracy:  0.465 lr:  0.04 reg:  0.05
# Validation accuracy:  0.398 lr:  0.04 reg:  0.1
# Validation accuracy:  0.316 lr:  0.04 reg:  0.15
# Validation accuracy:  0.302 lr:  0.04 reg:  0.2
# Validation accuracy:  0.286 lr:  0.04 reg:  0.25
# Validation accuracy:  0.555 lr:  0.1 reg:  0.0001
# Validation accuracy:  0.549 lr:  0.1 reg:  0.001
# Validation accuracy:  0.537 lr:  0.1 reg:  0.003
# Validation accuracy:  0.536 lr:  0.1 reg:  0.01
# Validation accuracy:  0.499 lr:  0.1 reg:  0.05
# Validation accuracy:  0.463 lr:  0.1 reg:  0.1
# Validation accuracy:  0.384 lr:  0.1 reg:  0.15
# Validation accuracy:  0.342 lr:  0.1 reg:  0.2
# Validation accuracy:  0.298 lr:  0.1 reg:  0.25
# Validation accuracy:  0.599 lr:  0.2 reg:  0.0001
# Validation accuracy:  0.583 lr:  0.2 reg:  0.001
# Validation accuracy:  0.585 lr:  0.2 reg:  0.003
# Validation accuracy:  0.558 lr:  0.2 reg:  0.01
# Validation accuracy:  0.512 lr:  0.2 reg:  0.05
# Validation accuracy:  0.463 lr:  0.2 reg:  0.1
# Validation accuracy:  0.39 lr:  0.2 reg:  0.15
# Validation accuracy:  0.34 lr:  0.2 reg:  0.2
# Validation accuracy:  0.267 lr:  0.2 reg:  0.25
# Validation accuracy:  0.591 lr:  0.3 reg:  0.0001
# Validation accuracy:  0.586 lr:  0.3 reg:  0.001
# Validation accuracy:  0.584 lr:  0.3 reg:  0.003
# Validation accuracy:  0.543 lr:  0.3 reg:  0.01
# Validation accuracy:  0.51 lr:  0.3 reg:  0.05
# Validation accuracy:  0.416 lr:  0.3 reg:  0.1
# Validation accuracy:  0.398 lr:  0.3 reg:  0.15
# Validation accuracy:  0.371 lr:  0.3 reg:  0.2
# Validation accuracy:  0.268 lr:  0.3 reg:  0.25
# Validation accuracy:  0.542 lr:  0.8 reg:  0.0001
# Validation accuracy:  0.593 lr:  0.8 reg:  0.001
# Validation accuracy:  0.587 lr:  0.8 reg:  0.003
# Validation accuracy:  0.522 lr:  0.8 reg:  0.01
# Validation accuracy:  0.473 lr:  0.8 reg:  0.05
# Validation accuracy:  0.418 lr:  0.8 reg:  0.1
# Validation accuracy:  0.317 lr:  0.8 reg:  0.15
# Validation accuracy:  0.322 lr:  0.8 reg:  0.2
# Validation accuracy:  0.254 lr:  0.8 reg:  0.25
# -----500------
# Validation accuracy:  0.223 lr:  0.01 reg:  0.0001
# Validation accuracy:  0.225 lr:  0.01 reg:  0.001
# Validation accuracy:  0.24 lr:  0.01 reg:  0.003
# Validation accuracy:  0.228 lr:  0.01 reg:  0.01
# Validation accuracy:  0.218 lr:  0.01 reg:  0.05
# Validation accuracy:  0.219 lr:  0.01 reg:  0.1
# Validation accuracy:  0.169 lr:  0.01 reg:  0.15
# Validation accuracy:  0.079 lr:  0.01 reg:  0.2
# Validation accuracy:  0.164 lr:  0.01 reg:  0.25
# Validation accuracy:  0.394 lr:  0.02 reg:  0.0001
# Validation accuracy:  0.387 lr:  0.02 reg:  0.001
# Validation accuracy:  0.389 lr:  0.02 reg:  0.003
# Validation accuracy:  0.386 lr:  0.02 reg:  0.01
# Validation accuracy:  0.339 lr:  0.02 reg:  0.05
# Validation accuracy:  0.302 lr:  0.02 reg:  0.1
# Validation accuracy:  0.244 lr:  0.02 reg:  0.15
# Validation accuracy:  0.22 lr:  0.02 reg:  0.2
# Validation accuracy:  0.191 lr:  0.02 reg:  0.25
# Validation accuracy:  0.489 lr:  0.03 reg:  0.0001
# Validation accuracy:  0.477 lr:  0.03 reg:  0.001
# Validation accuracy:  0.477 lr:  0.03 reg:  0.003
# Validation accuracy:  0.475 lr:  0.03 reg:  0.01
# Validation accuracy:  0.423 lr:  0.03 reg:  0.05
# Validation accuracy:  0.361 lr:  0.03 reg:  0.1
# Validation accuracy:  0.307 lr:  0.03 reg:  0.15
# Validation accuracy:  0.273 lr:  0.03 reg:  0.2
# Validation accuracy:  0.212 lr:  0.03 reg:  0.25
# Validation accuracy:  0.516 lr:  0.04 reg:  0.0001
# Validation accuracy:  0.515 lr:  0.04 reg:  0.001
# Validation accuracy:  0.506 lr:  0.04 reg:  0.003
# Validation accuracy:  0.498 lr:  0.04 reg:  0.01
# Validation accuracy:  0.466 lr:  0.04 reg:  0.05
# Validation accuracy:  0.404 lr:  0.04 reg:  0.1
# Validation accuracy:  0.347 lr:  0.04 reg:  0.15
# Validation accuracy:  0.307 lr:  0.04 reg:  0.2
# Validation accuracy:  0.286 lr:  0.04 reg:  0.25
# Validation accuracy:  0.569 lr:  0.1 reg:  0.0001
# Validation accuracy:  0.557 lr:  0.1 reg:  0.001
# Validation accuracy:  0.555 lr:  0.1 reg:  0.003
# Validation accuracy:  0.535 lr:  0.1 reg:  0.01
# Validation accuracy:  0.511 lr:  0.1 reg:  0.05
# Validation accuracy:  0.455 lr:  0.1 reg:  0.1
# Validation accuracy:  0.392 lr:  0.1 reg:  0.15
# Validation accuracy:  0.325 lr:  0.1 reg:  0.2
# Validation accuracy:  0.317 lr:  0.1 reg:  0.25
# Validation accuracy:  0.593 lr:  0.2 reg:  0.0001
# Validation accuracy:  0.582 lr:  0.2 reg:  0.001
# Validation accuracy:  0.58 lr:  0.2 reg:  0.003
# Validation accuracy:  0.552 lr:  0.2 reg:  0.01
# Validation accuracy:  0.508 lr:  0.2 reg:  0.05
# Validation accuracy:  0.42 lr:  0.2 reg:  0.1
# Validation accuracy:  0.421 lr:  0.2 reg:  0.15
# Validation accuracy:  0.296 lr:  0.2 reg:  0.2
# Validation accuracy:  0.283 lr:  0.2 reg:  0.25
# Validation accuracy:  0.575 lr:  0.3 reg:  0.0001
# Validation accuracy:  0.603 lr:  0.3 reg:  0.001
# Validation accuracy:  0.6 lr:  0.3 reg:  0.003
# Validation accuracy:  0.563 lr:  0.3 reg:  0.01
# Validation accuracy:  0.497 lr:  0.3 reg:  0.05
# Validation accuracy:  0.433 lr:  0.3 reg:  0.1
# Validation accuracy:  0.38 lr:  0.3 reg:  0.15
# Validation accuracy:  0.347 lr:  0.3 reg:  0.2
# Validation accuracy:  0.302 lr:  0.3 reg:  0.25
# Validation accuracy:  0.583 lr:  0.8 reg:  0.0001
# Validation accuracy:  0.584 lr:  0.8 reg:  0.001
# Validation accuracy:  0.587 lr:  0.8 reg:  0.003
# Validation accuracy:  0.552 lr:  0.8 reg:  0.01
# Validation accuracy:  0.477 lr:  0.8 reg:  0.05
# Validation accuracy:  0.374 lr:  0.8 reg:  0.1
# Validation accuracy:  0.343 lr:  0.8 reg:  0.15
# Validation accuracy:  0.323 lr:  0.8 reg:  0.2
# Validation accuracy:  0.22 lr:  0.8 reg:  0.25

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.583

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
